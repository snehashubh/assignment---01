# %%
import json
class admin:
    def __init__(self):
        self.food_item={}
        self.food_id= len(self.food_item)+1
    def add_new_food_item(self):
        self.name= input("enter food name: ")
        self.quanity = int(input("enter food quanity: "))
        self.price = int(input("enter food price: ")) 
        self.discount= input("enter food discount: ")
        self.stock = (input("enter food stock: "))
        self.item={"food name":self.name,"quanity":self.quanity,"price":self.price,"discount":self.discount,"stock":self.stock}
        self.food_id= len(self.food_item)+1
        self.food_item[self.food_id]=self.item
        with open ("food_item.json","w")as f:
            json.dump(self.food_item,f)
        return self.food_item
    def remove_item(self):
        food_item = int(input("enter the food id which you want to remove : "))
        del self.food_item [food_item]
        print("remaining food item is : ",self.food_item)
        with open ("food_item.json","w")as f:
            json.dump(self.food_item,f)
        return self.food_item
    def update_item(self):
        food_id=input("enter food id which you want to update: ")
        with open ("food_item",'r')as f:
            self.clear=json.load(f)
        if food_id not in self.clear:
            return "please enter a valid id"
        else:
            print(self.clear[food_id])
            while True:
                print("Press 0 For exit")
                print("Press 1 for Update Food Name")
                print("Press 2 for Update Quanity")
                print("Press 3 for Update Price")
                print("Press 4 for Update Discount")
                print("Press 5 for Update Stock")
                update_input = int(input("Enter Your Number Here :"))

                if update_input ==1:
                    food_name = input("Enter Your New Food Name :")
                    self.clear[food_id]["food_name"] = food_name
                    with open("food_item.json","w") as f:
                        json.dump(self.clear,f,indent=4)
                    print(self.clear[food_item])
                if update_input ==2:
                    food_name = input("Enter Your New Food quanity :")
                    self.clear[food_id]["food_quanity"] = food_name
                    with open("food_item.json","w") as f:
                        json.dump(self.clear,f,indent=4)
                    print(self.clear[food_item])
                   
                
                if update_input ==3:
                    food_name = input("Enter Your New Food price :")
                    self.clear[food_id]["food_price"] = food_name
                    with open("food_item.json","w") as f:
                        json.dump(self.clear,f,indent=4)
                    print(self.clear[food_item])
                if update_input ==4:
                    food_name = input("Enter Your New Food discount :")
                    self.clear[food_id]["food_discount"] = food_name
                    with open("food_item.json","w") as f:
                        json.dump(self.clear,f,indent=4)
                    print(self.clear[food_item])
                    
                if update_input ==5:
                    food_name = input("Enter Your New Food stock :")
                    self.clear[food_id]["food_stock"] = food_name
                    with open("food_item.json","w") as f:
                        json.dump(self.clear,f,indent=4)
                    print(self.clear[food_item])
                    break
               # For Watch the Food ID
    def view_food_id(self):
        l = []
        with open("food_item.json","r") as f:
            tem = json.load(f)
        for i in tem.keys():
            l.append(i)
        return l     
                    
                    
                    
                    
c= admin()
print (c.add_new_food_item()) 
print("**************************************************************************************")

print (c.add_new_food_item())
print("**************************************************************************************")

print (c.add_new_food_item())
print("**************************************************************************************")

print(c.update_item())
print("**************************************************************************************")

print(c.remove_item()) 
print("**************************************************************************************")

print(c.view_food_id())
print("**************************************************************************************")
